# %% [markdown]
# # *Tree*
#
# Prerequisites: [*Basics of python,list,method,OOPS concept*]

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# Q.Write an algorithm to compute the diameter of binary tree.The diameter of the binary tree is equal to the number of nodes on
#
# the logest path between any two leaves in it.
#
# Pictorial representation :
#
# ![image.png](attachment:image.png)
#
# Constraints:
#
# 1)Check if root is None then return 0, diameter
#
# 2)otherwise,
#
#     left_height, diameter = getDiameter(root.left, diameter)
#
#     right_height, diameter = getDiameter(root.right, diameter)
#
#     max_diameter = left_height + right_height + 1
#
#     diameter = max(diameter, max_diameter)
#
#     return max(left_height, right_height) + 1, diameter
#
# Sample input:
#
# root = Node(1)
#
# root.left = Node(2)
#
# root.right = Node(3)
#
# root.left.right = Node(4)
#
# root.right.left = Node(5)
#
# root.right.right = Node(6)
#
# root.right.left.left = Node(7)
#
# root.right.left.right = Node(8)
#
# Sample output:
#
# 6

# %% [markdown]
# #### Input Cell
# Run the below cell to initialize the inputs required for your exercise. Do not modify the contents of this cell.

# %%
#node to insert in the tree
n1=1
n2=2
n3=3

# %% [markdown]
# #### Code Cell
# Below is the code cell for **Exercise 1**. Type in your code in the cell.

# %%
##Excercise 1 code cell

class Node:
    def __init__(self, data, left=None, right=None):
        self.data = data
        self.left = left
        self.right = right



def getDiameter(root, diameter):

###BEGIN SOLUTION
    
    if root is None:
        return 0, diameter
    left_height, diameter = getDiameter(root.left, diameter)
    right_height, diameter = getDiameter(root.right, diameter)

    max_diameter = left_height + right_height + 1


    diameter = max(diameter, max_diameter)

    return max(left_height, right_height) + 1, diameter
    
###END SOLUTION

def getBTDiameter(root):

    diameter = 0
    return getDiameter(root, diameter)[1]


if __name__ == '__main__':

    root = Node(66)
    root.left = Node(65)
    root.right = Node(67)
    root.left.right = Node(65.5)
    root.right.left = Node(64)

root = Node(n1) 
root.left = Node(n2)
root.right = Node(n3)
# Out:
# The diameter of the tree is 5

# %% [markdown]
# #### Test Cases
# Run the below test cell to validate your code for **Exercise 1**. The cell has test cases your code should pass. Please do not modify the contents of this cell.

# %%
assert getBTDiameter(root) == 3
print("ALL PASSED!")

##################################################
# Out:
# ALL PASSED!

# %% [markdown]
# ----
# ## Exercise 2

# %% [markdown]
# Q.Write an algorithm to check if two binary trees are identical or not.If they have identical structure their contents are
#
# same.
#
# Constraints:
#
# 1) Check if x is None and y is None then return True
#
# 2) Otherwisereturn (x and y) and (x.key == y.key) and \isIdentical(x.left, y.left) and isIdentical(x.right, y.right)
#
# Sample input:
#
# x = Node(4)
#
# x.left = Node(2)
#
# x.right = Node(6)
#
# x.left.left = Node(1)
#
# x.left.right = Node(3)
#
# x.right.left = Node(5)
#
# x.right.right = Node(7)
#
# y = Node(4)
#
# y.left = Node(2)
#
# y.right = Node(6)
#
# y.left.left = Node(1)
#
# y.left.right = Node(3)
#
# y.right.left = Node(5)
#
# y.right.right = Node(7)
#
# Sample output:
#
# Given Binary Trees are identical

# %% [markdown]
# #### Input Cell
# Run the below cell to initialize the inputs required for your exercise. Do not modify the contents of this cell.

# %%
#node to insert to tree1
n1=10
n2=9
n3=11

# %% [markdown]
# #### Code Cell
# Below is the code cell for **Exercise 2**. Type your code in the cell.

# %%
class Node:
    def __init__(self, key=None, left=None, right=None):
        self.key = key
        self.left = left
        self.right = right

def isIdentical(x, y):    
###BEGIN SOLUTION
    
    if x is None and y is None:
        return True
    return (x and y) and (x.key == y.key) and \
            isIdentical(x.left, y.left) and isIdentical(x.right, y.right)

###END SOLUTION
if __name__ == '__main__':

    ## construct first tree
    x = Node(15)
    x.left = Node(10)
    x.right = Node(20)
    x.left.left = Node(8)
    x.left.right = Node(12)
    x.right.left = Node(16)
    x.right.right = Node(25)

    ## construct second tree
    y = Node(15)
    y.left = Node(10)
    y.right = Node(20)
    y.left.left = Node(8)
    y.left.right = Node(12)
    y.right.left = Node(16)
    y.right.right = Node(25)

    if isIdentical(x, y):
        print("Given Binary Trees are identical")
    else:
        print("Given Binary Trees are not identical")
# Out:
# Given Binary Trees are identical

# %% [markdown]
# #### Test Cases
# Run the below test cell to validate your code for **Exercise 2**. The cell has test cases your code should pass. Please do not modify the contents of this cell.

# %%
x=Node(n1)
x.left=Node(n2)
x.right=Node(n3)

y=Node(n1)
y.left=Node(n2)
y.right=Node(n3)

assert isIdentical(x, y) == True
print("ALL PASSED!")

#####################################################
# Out:
# ALL PASSED!

# %% [markdown]
# ----
# ## Exercise 3

# %% [markdown]
# Q.Write an efficient algorithm to comput the height of binarytree.The height or depth of the tree is number of edges or nodes on
#
# the longest path from root node to leaf node.
#
# Pictorial Presentation:
#
# ![image.png](attachment:image.png)
#
# To complete the height function:
#
# 1)Check if root is None the return 0
#
# 2)Otherwise return 1 + max(height(root.left), height(root.right))
#
# Sample Input:
#
#     root = Node(4)
#     root.left = Node(2)
#     root.right = Node(6)
#     root.left.left = Node(1)
#     root.left.right = Node(3)
#     root.right.left = Node(5)
#     root.right.right = Node(7)
#
# Sample Output:
#
#     3

# %% [markdown]
# #### Input Cell
# Run the below cell to initialize the inputs required for your exercise. Do not modify the contents of this cell.

# %%
#node to insert in a tree:
n1=60
n2=35
n3=77
n4=35
n5=10
n6=36
n7=8
n8=12

# %% [markdown]
# #### Code Cell
# Below is the code cell for **Exercise 3**. Type your code in the cell.

# %%
class Node:
    def __init__(self, key=None, left=None, right=None):
        self.key = key
        self.left = left
        self.right = right

def height(root):

###BEGIN SOLUTION
    
    if root is None:
        return 0
    return 1 + max(height(root.left), height(root.right))
    
###END SOLUTION
    
if __name__ == '__main__':

    root = Node(15)
    root.left = Node(10)
    root.right = Node(20)
    root.left.left = Node(8)
    root.left.right = Node(12)
    root.right.left = Node(16)
    root.right.right = Node(25)
    
    print("The height of the binary tree is", height(root))
# Out:
# The height of the binary tree is 3

# %% [markdown]
# #### Test Cases
# Run the below test cell to validate your code for **Exercise 3**. The cell has test cases your code should pass. Please do not modify the contents of this cell.

# %%
root = Node(n1)
root.left = Node(n2)
root.right = Node(n3)
assert height(root) == 2

root = Node(n4)
root.left = Node(n5)
root.right = Node(n6)
root.left.left = Node(n7)
root.left.right = Node(n8)
assert height(root) == 3
print("ALL PASSED!")

###################################################
# Out:
# ALL PASSED!

# %% [markdown]
# ----
# ## Exercise 4

# %% [markdown]
# Q.Write a Python program to check whether a given a binary tree is a valid binary search tree (BST) or not.
#
# Let a binary search tree (BST) is defined as follows:
#
# The left subtree of a node contains only nodes with keys less than the node's key.
#
# The right subtree of a node contains only nodes with keys greater than the node's key.
#
# Both the left and right subtrees must also be binary search trees.
#
# Constraint:
#
# 1)Perform while root or stack and while root
#
# 2)stack.append(root) and assign root.left to root and stack.pop to root.
#
# 3)Check if prev and root.val <= prev.val then return False assign root to prev and root.right to root then return True
#
# Example 1:
#
# Binary tree [2,1,3], return True.
#
# Example 2:
#
# Binary tree [1,2,3], return False.

# %% [markdown]
# #### Input Cell
# Run the below cell to initialize the inputs required for your exercise. Do not modify the contents of this cell.

# %%
#node to insert into the tree
n1=1
n2=2
n3=5
n4=6
n5=1
n6=10

# %% [markdown]
# #### Code Cell
# Below is the code cell for **Exercise 4**. Type your code in the cell.

# %%
class TreeNode(object):
    def __init__(self, x):
###BEGIN SOLUTION
        
        self.val = x
        self.left = None
        self.right = None
        
###END SOLUTION

def is_BST(root):
    stack = []
    prev = None
###BEGIN SOLUTION
    
    while root or stack:
        while root:
            stack.append(root)
            root = root.left
        root = stack.pop()
        if prev and root.val <= prev.val:
            return False
        prev = root
        root = root.right
    return True
    
###END SOLUTION
    
root = TreeNode(2)  
root.left = TreeNode(1)  
root.right = TreeNode(3) 
 
result = is_BST(root)
print(result)

root = TreeNode(1)  
root.left = TreeNode(2)  
root.right = TreeNode(3) 
 
result = is_BST(root)
print(result)
# Out:
# True
# False

# %% [markdown]
# #### Test Cases
# Run the below test cell to validate your code for **Exercise 4**. The cell has test cases your code should pass. Please do not modify the contents of this cell.

# %%
root = TreeNode(n1)  
root.left = TreeNode(n2)  
root.right = TreeNode(n3) 
assert is_BST(root) == False

root = TreeNode(n4)  
root.left = TreeNode(n5)  
root.right = TreeNode(n6) 
assert is_BST(root) == True

print("ALL PASSED!")

#####################################################
# Out:
# ALL PASSED!

# %% [markdown]
# ----
# ## Exercise 5

# %% [markdown]
# Q.Write a Python program to find the kth smallest element in a given a binary search tree.
#
# Constraints:
#
# 1)perform while root or stack and while root then stack.append(root) and assign root.left,stack.pop to root and decrement k by 1.
#
# 2)Check if k equals 0 then break and assign root.right to root.
#
# 3)Then return root.val.

# %% [markdown]
# #### Code Cell
# Below is the code cell for **Exercise 5**. Type your code in the cell.

# %%
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

def kth_smallest(root, k):
    stack = []
###BEGIN SOLUTION
    
    while root or stack:
        while root:
            stack.append(root)
            root = root.left
        root = stack.pop()
        k -= 1
        if k == 0:
            break
        root = root.right
    return root.val
    
###END SOLUTION
    
root = TreeNode(8)  
root.left = TreeNode(5)  
root.right = TreeNode(14) 
root.left.left = TreeNode(4)  
root.left.right = TreeNode(6) 
root.left.right.left = TreeNode(8)  
root.left.right.right = TreeNode(7)  
root.right.right = TreeNode(24) 
root.right.right.left = TreeNode(22)  

print(kth_smallest(root, 2))
print(kth_smallest(root, 3))
# Out:
# 5
# 8

# %% [markdown]
# #### Test Cases
# Run the below test cell to validate your code for **Exercise 5**. The cell has test cases your code should pass. Please do not modify the contents of this cell.

# %%
assert kth_smallest(root, 1) == 4
assert kth_smallest(root, 5) == 7
assert kth_smallest(root, 4) == 6
print("ALL PASSED!")

##################################################
# Out:
# ALL PASSED!
